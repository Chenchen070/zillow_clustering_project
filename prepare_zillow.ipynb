# %%
import pandas as pd
import numpy as np

# %%
import acquire_zillow

df = acquire_zillow.get_zillow_data()
df.head()
# Out:
#    basement_square_ft  bathroom  bedroom  parcelid  quality_type  \
# 0                 NaN       3.5      4.0  14297519           NaN
# 1                 NaN       1.0      2.0  17052889           NaN
# 2                 NaN       2.0      3.0  14186244           NaN
# 3                 NaN       3.0      4.0  12177905           8.0
# 4                 NaN       3.0      4.0  12095076           9.0
#
#    finished_square_ft  garage    fips    latitude    longitude  lot_square_ft  \
# 0              3100.0     2.0  6059.0  33634931.0 -117869207.0         4506.0
# 1              1465.0     1.0  6111.0  34449266.0 -119281531.0        12647.0
# 2              1243.0     2.0  6059.0  33886168.0 -117823170.0         8432.0
# 3              2376.0     NaN  6037.0  34245180.0 -118240722.0        13038.0
# 4              2962.0     NaN  6037.0  34145202.0 -118179824.0        63000.0
#
#        city  pool  yearbuilt  structure_value  house_value  land_value  \
# 0   53571.0   NaN     1998.0         485713.0    1023282.0    537569.0
# 1   13091.0   NaN     1967.0          88000.0     464000.0    376000.0
# 2   21412.0   1.0     1962.0          85289.0     564778.0    479489.0
# 3  396551.0   1.0     1970.0         108918.0     145143.0     36225.0
# 4   47019.0   1.0     1950.0         276684.0     773303.0    496619.0
#
#         tax  log_error transaction_date
# 0  11013.72   0.025595       2017-01-01
# 1   5672.48   0.055619       2017-01-01
# 2   6488.30   0.005383       2017-01-01
# 3   1777.51  -0.103410       2017-01-01
# 4   9516.26  -0.001011       2017-01-01

# %% [markdown]
# ### start clean up data

# %%
df.shape
# Out:
# (52441, 20)

# %%
# check duplicate for id number and keep the last transaction, 121 rows total
df.duplicated(subset=['parcelid']).sum()
# Out:
# 121

# %%
df = df.sort_values('transaction_date').drop_duplicates('parcelid',keep='last')
df.shape
# Out:
# (52320, 20)

# %%
# check for single unit
df[df['finished_square_ft'] == 0]
# Out:
# Empty DataFrame
# Columns: [basement_square_ft, bathroom, bedroom, parcelid, quality_type, finished_square_ft, garage, fips, latitude, longitude, lot_square_ft, city, pool, yearbuilt, structure_value, house_value, land_value, tax, log_error, transaction_date]
# Index: []

# %%
df[df['lot_square_ft'] == 0]
# Out:
# Empty DataFrame
# Columns: [basement_square_ft, bathroom, bedroom, parcelid, quality_type, finished_square_ft, garage, fips, latitude, longitude, lot_square_ft, city, pool, yearbuilt, structure_value, house_value, land_value, tax, log_error, transaction_date]
# Index: []

# %%
df[(df['bedroom'] == 0) & (df['bathroom'] == 0)]
# Out:
#        basement_square_ft  bathroom  bedroom  parcelid  quality_type  \
# 124                   NaN       0.0      0.0  14190895           NaN
# 2694                  NaN       0.0      0.0  12227894           4.0
# 2899                  NaN       0.0      0.0  12146026           NaN
# 3322                  NaN       0.0      0.0  14197244           NaN
# 4605                  NaN       0.0      0.0  14422107           NaN
# ...                   ...       ...      ...       ...           ...
# 49855                 NaN       0.0      0.0  13919043           NaN
# 50078                 NaN       0.0      0.0  17292931           NaN
# 51299                 NaN       0.0      0.0  12197543           5.0
# 52163                 NaN       0.0      0.0  12399434           6.0
# 52429                 NaN       0.0      0.0  11953526           NaN
#
#        finished_square_ft  garage    fips    latitude    longitude  \
# 124                   NaN     NaN  6059.0  33879900.0 -117801183.0
# 2694               1208.0     NaN  6037.0  33944448.0 -118268313.0
# 2899                280.0     NaN  6037.0  34113439.0 -118024905.0
# 3322                  NaN     NaN  6059.0  33898674.0 -117779067.0
# 4605                  NaN     NaN  6059.0  33500817.0 -117714728.0
# ...                   ...     ...     ...         ...          ...
# 49855              1719.0     NaN  6059.0  33803176.0 -117994180.0
# 50078                 NaN     NaN  6111.0  34127993.0 -118873772.0
# 51299               984.0     NaN  6037.0  33974459.0 -118261500.0
# 52163              2307.0     NaN  6037.0  33959173.0 -118107658.0
# 52429               892.0     NaN  6037.0  34102816.0 -118242343.0
#
#        lot_square_ft     city  pool  yearbuilt  structure_value  house_value  \
# 124          39184.0  21412.0   NaN        NaN         432623.0     830145.0
# 2694          3018.0  12447.0   NaN     1990.0          52011.0     185161.0
# 2899          8318.0  50749.0   1.0     1953.0           9137.0     963472.0
# 3322          9730.0  21412.0   NaN        NaN         384523.0     643406.0
# 4605         10619.0  25459.0   NaN        NaN        1504511.0    2909706.0
# ...              ...      ...   ...        ...              ...          ...
# 49855         6744.0  42967.0   NaN     1949.0          39661.0     125618.0
# 50078        43000.0  41673.0   NaN        NaN         358000.0     468439.0
# 51299         4000.0  12447.0   NaN     1927.0          34482.0     183027.0
# 52163        11880.0   4406.0   NaN     1948.0         149000.0     499000.0
# 52429         5201.0  12447.0   NaN        NaN           6394.0      34124.0
#
#        land_value       tax  log_error transaction_date
# 124      397522.0   9354.84  -0.001296       2017-01-03
# 2694     133150.0   2558.37  -0.024661       2017-01-19
# 2899     954335.0  11016.31  -0.661313       2017-01-20
# 3322     258883.0   7046.60   0.014172       2017-01-24
# 4605    1405195.0  29392.06   0.246856       2017-01-31
# ...           ...       ...        ...              ...
# 49855     85957.0   1873.60   0.020941       2017-09-05
# 50078    110439.0   4985.16   0.080163       2017-09-06
# 51299    148545.0   2300.32   0.238902       2017-09-12
# 52163    350000.0   6315.67   0.509534       2017-09-18
# 52429     27730.0    490.51  -0.159471       2017-09-19
#
# [103 rows x 20 columns]

# %%
# drop the rows that bedroom and bathroon count both 0, 103 raws total

df = df[(df['bedroom'] > 0) & (df['bathroom'] > 0)]
df.shape
# Out:
# (52169, 20)

# %%
# handle missing value

def nulls_by_col(df):
    num_missing = df.isnull().sum()
    rows = df.shape[0]
    prcnt_miss = num_missing / rows * 100
    cols_missing = pd.DataFrame({'num_rows_missing': num_missing, 'percent_rows_missing': prcnt_miss})
    return cols_missing.sort_values(by='num_rows_missing', ascending=False)

nulls_by_col(df).head()
# Out:
#                     num_rows_missing  percent_rows_missing
# basement_square_ft             52122             99.909908
# pool                           41105             78.792003
# garage                         34203             65.561924
# quality_type                   18541             35.540263
# city                            1028              1.970519

# %%
def nulls_by_row(df):
    num_missing = df.isnull().sum(axis=1)
    prcnt_miss = num_missing / df.shape[1] * 100
    rows_missing = pd.DataFrame({'num_cols_missing': num_missing, 'percent_cols_missing': prcnt_miss})
    rows_missing = df.merge(rows_missing,
                        left_index=True,
                        right_index=True)[['parcelid', 'num_cols_missing', 'percent_cols_missing']]
    return rows_missing.sort_values(by='num_cols_missing', ascending=False)

nulls_by_row(df).head()
# Out:
#         parcelid  num_cols_missing  percent_cols_missing
# 29967   14531743                 6                  30.0
# 18942   14261567                 6                  30.0
# 6809   167636512                 6                  30.0
# 15834   14316971                 6                  30.0
# 15072   14531755                 6                  30.0

# %%
def handle_missing_values(df, prop_required_columns=0.6, prop_required_row=0.75):
    threshold = int(round(prop_required_columns * len(df.index), 0))
    df = df.dropna(axis=1, thresh=threshold)
    threshold = int(round(prop_required_row * len(df.columns), 0))
    df = df.dropna(axis=0, thresh=threshold)
    return df

# %%
df = handle_missing_values(df)
df.shape
# Out:
# (52169, 17)

# %%
# convert fips to county name
df.fips = df.fips.astype(int)
df.fips = np.where(df.fips == 6037, 'LA', df.fips)
df.fips = np.where(df.fips == '6059', 'Orange', df.fips)
df.fips = np.where(df.fips == '6111', 'Ventura', df.fips)
df = df.rename(columns=({'fips':'county'}))
df.head()
# Out:
#    bathroom  bedroom  parcelid  quality_type  finished_square_ft   county  \
# 0       3.5      4.0  14297519           NaN              3100.0   Orange
# 1       1.0      2.0  17052889           NaN              1465.0  Ventura
# 2       2.0      3.0  14186244           NaN              1243.0   Orange
# 3       3.0      4.0  12177905           8.0              2376.0       LA
# 4       3.0      4.0  12095076           9.0              2962.0       LA
#
#      latitude    longitude  lot_square_ft      city  yearbuilt  \
# 0  33634931.0 -117869207.0         4506.0   53571.0     1998.0
# 1  34449266.0 -119281531.0        12647.0   13091.0     1967.0
# 2  33886168.0 -117823170.0         8432.0   21412.0     1962.0
# 3  34245180.0 -118240722.0        13038.0  396551.0     1970.0
# 4  34145202.0 -118179824.0        63000.0   47019.0     1950.0
#
#    structure_value  house_value  land_value       tax  log_error  \
# 0         485713.0    1023282.0    537569.0  11013.72   0.025595
# 1          88000.0     464000.0    376000.0   5672.48   0.055619
# 2          85289.0     564778.0    479489.0   6488.30   0.005383
# 3         108918.0     145143.0     36225.0   1777.51  -0.103410
# 4         276684.0     773303.0    496619.0   9516.26  -0.001011
#
#   transaction_date
# 0       2017-01-01
# 1       2017-01-01
# 2       2017-01-01
# 3       2017-01-01
# 4       2017-01-01

# %%
# handle outliers

def iqr_outliers(df, k=1.5, col_list=None):
    if col_list != None:
        for col in col_list:
            q1, q3 = df[col].quantile([.25, .75])
            iqr = q3 - q1
            upper_bound = q3 + k * iqr
            lower_bound = q1 - k * iqr
            df = df[(df[col] > lower_bound) & (df[col] < upper_bound)]
    else:
        for col in list(df):
            q1, q3 = df[col].quantile([.25, .75])
            iqr = q3 - q1
            upper_bound = q3 + k * iqr
            lower_bound = q1 - k * iqr
            df = df[(df[col] > lower_bound) & (df[col] < upper_bound)]

    return df

# %%
outlier_cols = ['finished_square_ft', 'lot_square_ft', 'structure_value', 'house_value', 'land_value','tax']
df = iqr_outliers(df, col_list=outlier_cols)
df = df[df.bedroom <= 6]
df = df[df.bathroom <= 6]
df = df[df.house_value < 2000000]
df.shape
# Out:
# (40298, 17)

# %%
# convert latitude and longitude

df.latitude = df.latitude / 1_000_000
df.longitude = df.longitude / 1_000_000

# %%
# creat age colums
df['age'] = 2017 - df.yearbuilt
df['room_count'] = df.bathroom + df.bedroom
df.head()
# Out:
#     bathroom  bedroom  parcelid  quality_type  finished_square_ft   county  \
# 1        1.0      2.0  17052889           NaN              1465.0  Ventura
# 2        2.0      3.0  14186244           NaN              1243.0   Orange
# 5        1.0      2.0  12069064           5.0               738.0       LA
# 49       2.0      3.0  12871444           4.0              1059.0       LA
# 48       1.0      2.0  11023776           4.0               776.0       LA
#
#      latitude   longitude  lot_square_ft     city  yearbuilt  structure_value  \
# 1   34.449266 -119.281531        12647.0  13091.0     1967.0          88000.0
# 2   33.886168 -117.823170         8432.0  21412.0     1962.0          85289.0
# 5   34.149214 -118.239357         4214.0  45457.0     1922.0          18890.0
# 49  34.083661 -117.735137         7215.0  20008.0     1955.0          51776.0
# 48  34.250870 -118.421788         7055.0  12447.0     1946.0          38030.0
#
#     house_value  land_value      tax  log_error transaction_date   age  \
# 1      464000.0    376000.0  5672.48   0.055619       2017-01-01  50.0
# 2      564778.0    479489.0  6488.30   0.005383       2017-01-01  55.0
# 5      218552.0    199662.0  2366.08   0.101723       2017-01-01  95.0
# 49     187119.0    135343.0  2481.45   0.036263       2017-01-02  62.0
# 48     164836.0    126806.0  2086.91   0.093134       2017-01-02  71.0
#
#     room_count
# 1          3.0
# 2          5.0
# 5          3.0
# 49         5.0
# 48         3.0

# %%
df.shape
# Out:
# (40298, 19)

# %%
40298/52441
# Out:
# 0.7684445376709064

# %%
# write a function of cleaning

def clean_zillow(df):
    df = df.sort_values('transaction_date').drop_duplicates('parcelid',keep='last')
    df = df[(df['bedroom'] > 0) & (df['bathroom'] > 0)]
    df = handle_missing_values(df)
    df.fips = df.fips.astype(int)
    df.fips = np.where(df.fips == 6037, 'LA', df.fips)
    df.fips = np.where(df.fips == '6059', 'Orange', df.fips)
    df.fips = np.where(df.fips == '6111', 'Ventura', df.fips)
    df = df.rename(columns=({'fips':'county'}))
    outlier_cols = ['finished_square_ft', 'lot_square_ft', 'structure_value', 'house_value', 'land_value','tax']
    df = iqr_outliers(df, col_list=outlier_cols)
    df = df[df.bedroom <= 6]
    df = df[df.bathroom <= 6]
    df = df[df.house_value < 2000000]
    df.latitude = df.latitude / 1_000_000
    df.longitude = df.longitude / 1_000_000
    df['age'] = 2017 - df.yearbuilt
    df['room_count'] = df.bathroom + df.bedroom
    return df

# %% [markdown]
# ### split the data

# %%
# before we impoute the data, split the data first

from sklearn.model_selection import train_test_split

train_validate, test = train_test_split(df,test_size=0.2, random_state=123)
train, validate = train_test_split(train_validate,test_size=0.3, random_state=123)

train.shape,validate.shape, test.shape
# Out:
# ((22566, 19), (9672, 19), (8060, 19))

# %%
def split_data(df):
    train_validate, test = train_test_split(df,test_size=0.2, random_state=123)
    train, validate = train_test_split(train_validate,test_size=0.3, random_state=123)
    
    return train, validate, test

# %% [markdown]
# ### impute the data

# %%
def impute_missing_value_zillow(df):
    df['quality_type'] = df.quality_type.fillna(round(df.quality_type.mean()))
    df.dropna(inplace=True)
    return df
